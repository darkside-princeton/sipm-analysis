# %%
from sipm.analysis.AdvancedAnalyzer import AdvancedAnalyzer

# %%
a = AdvancedAnalyzer(
    dir='/scratch/gpfs/as111/results/',
    voltages=[63,65,67,69,71],
    channels=[0,1,2,3],
    positions=['top','bottom']
)

# %%
a.load_files(date='2022-11-22',light='laser',coinc='laser',cond='calibration',run='*',wf=False,verbose=True)
# Out:
# 2022-11-22 63 top laser coinc=laser cond=calibration run* - 20 files 219823 events
# 2022-11-22 65 top laser coinc=laser cond=calibration run* - 20 files 219816 events
# 2022-11-22 67 top laser coinc=laser cond=calibration run* - 20 files 219803 events
# 2022-11-22 69 top laser coinc=laser cond=calibration run* - 20 files 219813 events
# 2022-11-22 71 top laser coinc=laser cond=calibration run* - 20 files 219812 events
# 2022-11-22 63 bottom laser coinc=laser cond=calibration run* - 20 files 219820 events
# 2022-11-22 65 bottom laser coinc=laser cond=calibration run* - 20 files 219811 events
# 2022-11-22 67 bottom laser coinc=laser cond=calibration run* - 20 files 219809 events
# 2022-11-22 69 bottom laser coinc=laser cond=calibration run* - 20 files 219821 events
# 2022-11-22 71 bottom laser coinc=laser cond=calibration run* - 20 files 219799 events

# %%
a.print_info()
# Out:
# Data structure:
#  level1=position level2=channel level3=voltage
# bottom:
#   0:
#     63:
#       amplitude_trig: []
#       baseline_mean: []
#       baseline_rms: []
#       integral_5p00us: []
#       peakpos_trig: []
#     65:
#       amplitude_trig: []
#       baseline_mean: []
#       baseline_rms: []
#       integral_5p00us: []
#       peakpos_trig: []
#     67:
#       amplitude_trig: []
#       baseline_mean: []
#       baseline_rms: []
#       integral_5p00us: []
#       peakpos_trig: []
#     69:
#       amplitude_trig: []
#       baseline_mean: []
#       baseline_rms: []
#       integral_5p00us: []
#       peakpos_trig: []
#     71:
#       amplitude_trig: []
#       baseline_mean: []
#       baseline_rms: []
#       integral_5p00us: []
#       peakpos_trig: []
#   1:
#     63:
#       amplitude_trig: []
#       baseline_mean: []
#       baseline_rms: []
#       integral_5p00us: []
#       peakpos_trig: []
#     65:
#       amplitude_trig: []
#       baseline_mean: []
# ...
